# %%
import math
import numpy as np
import pandas as pd
from pathlib import Path

PROFILE_SECONDS = 15.0
DATA_DIR = Path('/home/ac.zzheng/power/GPGPU/data/H100')
power_cap = 1800
gpu_counts = [1, 2, 3, 4]

spec_dir = DATA_DIR / 'spec_power_motif'
ml_dir = DATA_DIR / 'ml_power_motif'
spec_benchmarks = [d.name for d in spec_dir.iterdir() if d.is_dir()]
ml_benchmarks = [d.name for d in ml_dir.iterdir() if d.is_dir()]
all_configs = [(spec_dir, spec_benchmarks), (ml_dir, ml_benchmarks)]


def extract_metrics_from_csv(csv_path, gpu_count):
    df = pd.read_csv(csv_path)
    if len(df) < 2:
        return None
    if 'GPU0_DRAM_Active' in df.columns:
        df = df[df['GPU0_DRAM_Active'] != 0.0]
    if len(df) == 0:
        return None
    t0 = df['Time (s)'].min()
    df = df[df['Time (s)'] <= t0 + PROFILE_SECONDS]
    if len(df) == 0:
        return None
    active = [i for i in range(gpu_count) if f'GPU{i}_Power (W)' in df.columns]
    if not active:
        return None

    p_avg, dr_avg, sm_avg = {}, {}, {}
    fp16_avg, fp32_avg, fp64_avg = {}, {}, {}
    for gid in active:
        p_avg[gid] = df[f'GPU{gid}_Power (W)'].mean()
        sm_avg[gid] = df[f'GPU{gid}_SM_Clock (MHz)'].mean() if f'GPU{gid}_SM_Clock (MHz)' in df.columns else 0
        dr_avg[gid] = df[f'GPU{gid}_DRAM_Active'].mean() if f'GPU{gid}_DRAM_Active' in df.columns else 0
        fp16_avg[gid] = df[f'GPU{gid}_FP16_Active'].mean() if f'GPU{gid}_FP16_Active' in df.columns else 0
        fp32_avg[gid] = df[f'GPU{gid}_FP32_Active'].mean() if f'GPU{gid}_FP32_Active' in df.columns else 0
        fp64_avg[gid] = df[f'GPU{gid}_FP64_Active'].mean() if f'GPU{gid}_FP64_Active' in df.columns else 0

    def safe(v):
        return 0.0 if (v is None or (isinstance(v, float) and math.isnan(v))) else v

    dr_list = [safe(dr_avg[g]) for g in active]
    sm_list = [safe(sm_avg[g]) for g in active]
    fp_list = [safe(fp16_avg[g]) + safe(fp32_avg[g]) + safe(fp64_avg[g]) for g in active]

    return {
        'avg_power': safe(np.mean([safe(p_avg[g]) for g in active])),
        'dram_sum': sum(dr_list),
        'sm_sum': sum(sm_list),
        'fp_sum': sum(fp_list),
    }


def load_runtime_spec(app_dir, power_cap):
    """Load runtime from runtime.csv for SPEC apps."""
    runtime_csv = app_dir / 'runtime.csv'
    if not runtime_csv.exists():
        return {}
    rt_df = pd.read_csv(runtime_csv)
    rt_df = rt_df[rt_df['power_cap'] == power_cap]
    return {int(row['gpu_count']): row['runtime_seconds'] for _, row in rt_df.iterrows()}


def get_runtime_from_csv(csv_path):
    """Get runtime as max Time (s) from gpu_metrics CSV for ML apps."""
    df = pd.read_csv(csv_path)
    if 'Time (s)' not in df.columns or len(df) == 0:
        return float('nan')
    return df['Time (s)'].max()


txt_lines = []
for base_dir, benchmarks in all_configs:
    suite = 'SPEC' if 'spec' in str(base_dir) else 'ML'
    is_ml = suite == 'ML'
    runtimes_spec = {}
    for app in sorted(benchmarks):
        app_lines = []
        if not is_ml:
            runtimes_spec = load_runtime_spec(base_dir / app, power_cap)
        for gc in gpu_counts:
            csv_file = base_dir / app / f"{power_cap}_{gc}_gpu_metrics.csv"
            if not csv_file.exists():
                continue
            metrics = extract_metrics_from_csv(csv_file, gc)
            if metrics is None:
                continue
            if is_ml:
                perf = get_runtime_from_csv(csv_file)
            else:
                perf = runtimes_spec.get(gc, float('nan'))
            app_lines.append((gc, perf, metrics))

        if app_lines:
            # Sort by performance (runtime ascending = best first)
            app_lines.sort(key=lambda x: x[1])
            txt_lines.append(f"\n===== {suite}/{app} =====")
            txt_lines.append(f"cap={power_cap}")
            txt_lines.append("gpu_count\tperformance\tavg_power\tdram_sum\tsm_sum\tfp_sum")
            for gc, perf, m in app_lines:
                txt_lines.append(
                    f"{gc}\t{perf:.2f}\t{m['avg_power']:.2f}\t{m['dram_sum']:.2f}\t{m['sm_sum']:.2f}\t{m['fp_sum']:.2f}"
                )

txt_output = '\n'.join(txt_lines)
txt_path = DATA_DIR / 'perf_metrics.txt'
txt_path.write_text(txt_output)
print(txt_output)
print(f"\n[written] {txt_path}")
# Out:
# ===== SPEC/cloverleaf =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 4	16.83	389.91	2.12	7882.50	0.27
# 3	19.37	426.96	1.79	5940.00	0.23
# 2	22.66	500.29	1.46	3960.00	0.19
# 1	36.99	569.53	0.80	1980.00	0.10
#
# ===== SPEC/hpgmg =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 1	10.09	303.11	0.22	1980.00	0.06
# 2	11.95	248.33	0.30	3960.00	0.08
# 3	42.93	138.73	0.08	5940.00	0.02
# 4	395.00	143.64	0.15	7920.00	0.03
#
# ===== SPEC/lbm =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 4	18.82	285.17	0.52	7920.00	0.71
# 3	21.98	295.44	0.39	5940.00	0.54
# 2	29.83	308.18	0.27	3960.00	0.37
# 1	55.41	326.74	0.13	1980.00	0.19
#
# ===== SPEC/minisweep =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 4	43.61	141.45	0.09	7920.00	0.04
# 3	57.47	141.75	0.06	5940.00	0.03
# 2	77.25	149.37	0.04	3960.00	0.02
# 1	140.82	166.53	0.03	1980.00	0.01
#
# ===== SPEC/miniweather =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 1	57.01	487.05	0.28	1980.00	0.08
# 2	82.00	213.61	0.00	3960.00	0.05
# 4	83.89	139.50	0.01	7920.00	0.00
# 3	84.09	160.00	0.03	5940.00	0.03
#
# ===== SPEC/pot3d =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 4	102.72	158.43	0.28	7920.00	0.01
# 3	104.33	173.49	0.28	5940.00	0.01
# 2	109.34	201.76	0.25	3960.00	0.01
# 1	133.09	266.32	0.21	1980.00	0.00
#
# ===== SPEC/tealeaf =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 4	16.21	411.55	2.56	7800.00	0.09
# 3	20.74	434.88	2.02	5940.00	0.07
# 2	25.19	484.32	1.49	3960.00	0.05
# 1	41.04	554.58	0.81	1980.00	0.03
#
# ===== ML/bert =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 4	21.03	397.91	0.93	7757.73	0.94
# 3	24.34	425.87	0.76	5940.00	0.78
# 2	26.42	409.67	0.48	3960.00	0.49
# 1	37.94	455.53	0.25	1980.00	0.28
#
# ===== ML/gpt2 =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 3	17.43	429.06	0.54	5935.00	1.07
# 2	18.02	521.86	0.46	3960.00	0.91
# 4	18.79	361.54	0.48	7920.00	0.97
# 1	22.97	595.42	0.26	1980.00	0.53
#
# ===== ML/resnet50 =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 4	20.85	339.16	1.46	7328.18	0.04
# 3	21.01	434.59	1.47	5939.17	0.04
# 2	25.65	435.67	0.88	3960.00	0.02
# 1	39.08	533.17	0.58	1980.00	0.02
#
# ===== ML/vgg16 =====
# cap=1800
# gpu_count	performance	avg_power	dram_sum	sm_sum	fp_sum
# 1	13.39	411.40	0.26	1980.00	0.05
# 3	15.13	203.97	0.22	5940.00	0.04
# 2	15.52	247.05	0.22	3960.00	0.04
# 4	16.26	191.40	0.24	7644.00	0.05
#
# [written] /home/ac.zzheng/power/GPGPU/data/H100/perf_metrics.txt
